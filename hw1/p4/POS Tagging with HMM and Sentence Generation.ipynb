# %%
import nltk
import os

# %%
#C(wi, ti)
word_tag_counts = {}

#C(ti)
tag_unigram_counts = {}

# C(ti−1, ti)
tag_bigram_counts = {}


files = os.listdir('brown_train')
for file in files:

    text = open('brown_train/' + file).read()
    text = text.replace('\t', '')
    sentences = text.splitlines()
    for sent in sentences:
        if sent == '':
            continue
        
        word_tag = sent.split()
        word_tag.insert(0, '/start')
        word_tag.append('/end')
        for i in range(0, len(word_tag)):
            word, tag = word_tag[i].rsplit('/', 1)

            try:
                word_tag_counts[(word,tag)] += 1
            except:
                word_tag_counts[(word,tag)] = 1

            try:
                tag_unigram_counts[tag] += 1
            except:
                tag_unigram_counts[tag] = 1

            if i > 0:
                try:
                    tag_bigram_counts[previous_tag, tag] += 1
                except:
                    tag_bigram_counts[previous_tag, tag] = 1
            previous_tag = tag;

# %%
# write to file
with open('word_tag_counts.txt','w') as f:
    f.write(str(word_tag_counts))
with open('tag_unigram_counts.txt','w') as f:
    f.write(str(tag_unigram_counts))
with open('tag_bigram_counts.txt','w') as f:
    f.write(str(tag_bigram_counts))

# %%
#P(ti−1, ti) = C(ti−1, ti) / C(ti−1)
def cal_transition_prob(tag1, tag2):
    try:
        return tag_bigram_counts[(tag1, tag2)] / tag_unigram_counts[tag1]
    except:
        return 0
    
transition_prob = {}

files = os.listdir('brown_train')
for file in files:

    text = open('brown_train/' + file).read()
    text = text.replace('\t', '')
    sentences = text.splitlines()
    for sent in sentences:
        if sent == '':
            continue
        
        word_tag = sent.split()
        word_tag.insert(0, '/start')
        word_tag.append('/end')
        for i in range(0, len(word_tag)):
            word, tag = word_tag[i].rsplit('/', 1)
            
            if i > 0:
                prob = cal_transition_prob(previous_tag, tag)
                transition_prob[previous_tag, tag] = prob
               
            previous_tag = tag;

# %%
#P(wi, ti) = C(wi, ti) / C(ti)

def cal_emission_probability(word, tag):
    try:
        return word_tag_counts[(word, tag)] / tag_unigram_counts[tag]
    except:
        return 0
    
emission_prob = {}

files = os.listdir('brown_train')
for file in files:

    text = open('brown_train/' + file).read()
    text = text.replace('\t', '')
    sentences = text.splitlines()
    for sent in sentences:
        if sent == '':
            continue
        
        word_tag = sent.split()
        word_tag.insert(0, '/start')
        word_tag.append('/end')
        for i in range(0, len(word_tag)):
            word, tag = word_tag[i].rsplit('/', 1)
            
            prob = cal_emission_probability(word, tag)
            emission_prob[word, tag] = prob

# %%
import random
def generate_sentence():
    sentence = ""
    probabilities = 1.0
    
    previous_tag = 'start'
    while(True):
        tags_choice = []
        tag_probabilities = []
        for tags, prob in transition_prob.items():
            if tags[0] == previous_tag:
                tags_choice.append(tags[1])
                tag_probabilities.append(prob)
                
        tag_draw = random.choices(tags_choice, weights = tag_probabilities, k = 1)[0]
        probabilities *= tag_probabilities[tags_choice.index(tag_draw)]
        previous_tag = tag_draw
        
        if tag_draw == 'end':
            break

        words = []
        word_probabilities = []
        for wordtag, count in emission_prob.items():
            if wordtag[1] == tag_draw:
                words.append(wordtag[0])
                word_probabilities.append(count)
        generated_word = random.choices(words, weights = word_probabilities, k = 1)[0]
        sentence += generated_word + " "
        
        probabilities *= word_probabilities[words.index(generated_word)]

    return sentence, probabilities

# %%
f = open(" random_sentences.txt", "w")
for i in range(0, 3):
    sent, prob = generate_sentence()
    f.write("sentence: " + sent + ", probability: " + str(prob) + "\n\n")
f.close()

# %%
#how to deal with unknown words????
#unknown word which tag? transition prob is 0

def Viterbi(sentence):
    # what is the list of all tags?
    distinct_tags = list(tag_unigram_counts.keys())

    #sentence = ["I", "saw", "her", "duck" ]
    sentlen = len(sentence)

    # viterbi:
    # for each step i in 1 .. sentlen,
    # store a dictionary
    # that maps each tag X
    # to the probability of the best tag sequence of length i that ends in X
    viterbi = [ ]

    # backpointer:
    # for each step i in 1..sentlen,
    # store a dictionary
    # that maps each tag X
    # to the previous tag in the best tag sequence of length i that ends in X
    backpointer = [ ]

    first_viterbi = { }
    first_backpointer = { }
    for tag in distinct_tags:
        # don't record anything for the START tag
        if tag == "start": 
            continue
        first_viterbi[ tag ] = cal_transition_prob('start', tag) * cal_emission_probability(sentence[0], tag) #cpd_tags["START"].prob(tag) * cpd_tagwords[tag].prob( sentence[0] )
        first_backpointer[ tag ] = "start"

    #print(first_viterbi)
    #print(first_backpointer)

    viterbi.append(first_viterbi)
    backpointer.append(first_backpointer)

    currbest = max(first_viterbi.keys(), key = lambda tag: first_viterbi[ tag ])
    print( "Word", "'" + sentence[0] + "'", "current best two-tag sequence:", first_backpointer[ currbest], currbest)
    # print( "Word", "'" + sentence[0] + "'", "current best tag:", currbest)

    for wordindex in range(1, len(sentence)):
        this_viterbi = { }
        this_backpointer = { }
        prev_viterbi = viterbi[-1]

        for tag in distinct_tags:
            # don't record anything for the START tag
            if tag == "start": continue

            # if this tag is X and the current word is w, then 
            # find the previous tag Y such that
            # the best tag sequence that ends in X
            # actually ends in Y X
            # that is, the Y that maximizes
            # prev_viterbi[ Y ] * P(X | Y) * P( w | X)
            # The following command has the same notation
            # that you saw in the sorted() command.

            best_previous = ""
            best_prob = 0.0

            for prevtag in distinct_tags:

                prob = prev_viterbi.get(prevtag, 0) * cal_transition_prob(prevtag, tag) * cal_emission_probability(sentence[wordindex], tag)
                if prob >= best_prob:
                    best_previous = prevtag
                    best_prob = prob

            this_viterbi[ tag ] = prev_viterbi[ best_previous] * cal_transition_prob(best_previous, tag) * cal_emission_probability(sentence[wordindex], tag)

            this_backpointer[ tag ] = best_previous

        currbest = max(this_viterbi.keys(), key = lambda tag: this_viterbi[ tag ])
        print( "Word", "'" + sentence[ wordindex] + "'", "current best two-tag sequence:", this_backpointer[ currbest], currbest)
        # print( "Word", "'" + sentence[ wordindex] + "'", "current best tag:", currbest)


        # done with all tags in this iteration
        # so store the current viterbi step
        viterbi.append(this_viterbi)
        backpointer.append(this_backpointer)


    # done with all words in the sentence.
    # now find the probability of each tag
    # to have "END" as the next tag,
    # and use that to find the overall best sequence
    prev_viterbi = viterbi[-1]
    best_previous = max(prev_viterbi.keys(),
                        key = lambda prevtag: prev_viterbi[ prevtag ] * cal_transition_prob(prevtag, 'end'))

    prob_tagsequence = prev_viterbi[ best_previous ] * cal_transition_prob(best_previous, 'end')

    # best tagsequence: we store this in reverse for now, will invert later
    best_tagsequence = [ "end", best_previous ]
    # invert the list of backpointers
    backpointer.reverse()

    # go backwards through the list of backpointers
    # (or in this case forward, because we have inverter the backpointer list)
    # in each case:
    # the following best tag is the one listed under
    # the backpointer for the current best tag
    current_best_tag = best_previous
    for bp in backpointer:
        best_tagsequence.append(bp[current_best_tag])
        current_best_tag = bp[current_best_tag]

    best_tagsequence.reverse()
    print( "The sentence was:", end = " ")
    for w in sentence: print( w, end = " ")
    print("\n")
    print( "The best tag sequence is:", end = " ")
    for t in best_tagsequence: print (t, end = " ")
    print("\n")
    print( "The probability of the best tag sequence is:", prob_tagsequence)
    return best_tagsequence

# %%
Viterbi(['He', 'goes', 'to','kjhkjh', 'school'])
# Out:
# Word 'He' current best two-tag sequence: start pps
# ('goes', 'vbz')
# ('to', 'in')
# ('to', 'in-tl')
# ('to', 'to')
# ('to', 'ql')
# ('to', 'nps')
# ('to', 'in-hl')
# ('to', 'to-hl')
# ('to', 'in-nc')
# ('to', 'nil')
# ('to', 'to-nc')
# ('school', 'nn-tl')
# ('school', 'nn')
# ('school', 'vb')
# ('school', 'nn-hl')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-289-ce9a62e1785a> in <module>
# ----> 1 Viterbi(['He', 'goes', 'to','kjhkjh', 'school'])
#
# <ipython-input-288-3fcaea7ba7ed> in Viterbi(sentence)
#     115     current_best_tag = best_previous
#     116     for bp in backpointer:
# --> 117         print(bp[current_best_tag], "  ", current_best_tag, "\n")
#     118         best_tagsequence.append(bp[current_best_tag])
#     119         current_best_tag = bp[current_best_tag]
#
# KeyError: 'fw-uh-tl'

# %%
word_tag_counts.get(('to',  'fw-uh-tl')) is None
# Out:
# True

# %%
result = []
sentence = []
with open('Test_File.txt', 'r') as f:
    for line in f:
        line = line.replace('\n', '')
        if line.startswith('< EOS >'):
            result.append(sentence)
            sentence = []
        else:
            sentence.append(line)
f = open("Viterbi algorithm.txt", "w")
for sentence in result:
    f.write(sentence[0] + "\n")
    
    sentence = sentence[1:]
    tags = Viterbi(sentence)[1:-1]
    for i in range(0, len(sentence)):
        f.write(sentence[i] + "/" + tags[i] + "\n")
    f.write('< EOS >' + "\n")
    
f.close()
# Out:
# Word 'The' current best two-tag sequence: start at
# Word 'aged' current best two-tag sequence: at vbn
# Word 'care' current best two-tag sequence: vbn nn
# Word 'plan' current best two-tag sequence: nn nn
# Word 'carries' current best two-tag sequence: nn vbz
# Word 'these' current best two-tag sequence: vbz dts
# Word 'benefits' current best two-tag sequence: dts nns
# Word 'for' current best two-tag sequence: nns in
# Word 'persons' current best two-tag sequence: in nns
# Word 'over' current best two-tag sequence: nns in
# Word '65' current best two-tag sequence: in cd
# Word 'who' current best two-tag sequence: cd wps
# Word 'are' current best two-tag sequence: wps ber
# Word 'under' current best two-tag sequence: ber in
# Word 'the' current best two-tag sequence: in at
# Word 'social' current best two-tag sequence: at jj
# Word 'security' current best two-tag sequence: jj nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'railroad' current best two-tag sequence: cc nn
# Word 'retirement' current best two-tag sequence: nn nn
# Word 'systems' current best two-tag sequence: nn nns
# Word ':' current best two-tag sequence: nns :
# Word '1' current best two-tag sequence: : cd-hl
# The sentence was: The aged care plan carries these benefits for persons over 65 who are under the social security and railroad retirement systems : 1
#
# The best tag sequence is: start at vbn nn nn vbz dts nns in nns in cd wps ber in at jj nn cc nn nn nns : cd-hl end
#
# The probability of the best tag sequence is: 2.0061023526445486e-76
# Word 'They' current best two-tag sequence: start ppss
# Word 'would' current best two-tag sequence: ppss md
# Word 'still' current best two-tag sequence: md rb
# Word 'be' current best two-tag sequence: rb be
# Word 'paid' current best two-tag sequence: be vbn
# Word 'by' current best two-tag sequence: vbn in
# Word 'the' current best two-tag sequence: in at
# Word 'patient' current best two-tag sequence: at nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: They would still be paid by the patient .
#
# The best tag sequence is: start ppss md rb be vbn in at nn . end
#
# The probability of the best tag sequence is: 1.9583493998781075e-19
# Word 'The' current best two-tag sequence: start at
# Word 'cases' current best two-tag sequence: at nns
# Word 'involved' current best two-tag sequence: nns vbn
# Word 'judges' current best two-tag sequence: vbn nns
# Word 'in' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word '33d' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word '24th' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word '42d' current best two-tag sequence: fw-uh-tl at
# Word 'precincts' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '31st' current best two-tag sequence: fw-uh-tl at
# Word 'ward' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '21st' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word '28th' current best two-tag sequence: fw-uh-tl at
# Word 'precincts' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '29th' current best two-tag sequence: fw-uh-tl at
# Word 'ward' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '18th' current best two-tag sequence: fw-uh-tl at
# Word 'precinct' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '4th' current best two-tag sequence: fw-uh-tl at
# Word 'ward' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '9th' current best two-tag sequence: fw-uh-tl at
# Word 'precinct' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '23d' current best two-tag sequence: fw-uh-tl at
# Word 'ward' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: The cases involved judges in the 33d , 24th , and 42d precincts of the 31st ward , the 21st and 28th precincts of the 29th ward , the 18th precinct of the 4th ward , and the 9th precinct of the 23d ward .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'House' current best two-tag sequence: start nn-tl
# Word 'Speaker' current best two-tag sequence: nn-tl nn-tl
# Word 'Sam' current best two-tag sequence: nn-tl np
# Word 'Rayburn' current best two-tag sequence: np np
# Word '(' current best two-tag sequence: np (
# Word 'D.' current best two-tag sequence: ( np
# Word ',' current best two-tag sequence: np ,
# Word 'Tex.' current best two-tag sequence: , np
# Word ')' current best two-tag sequence: np )
# Word 'called' current best two-tag sequence: ) vbd
# Word 'the' current best two-tag sequence: vbd at
# Word 'Kennedy' current best two-tag sequence: at np
# Word 'program' current best two-tag sequence: np nn
# Word '``' current best two-tag sequence: nn ``
# Word 'a' current best two-tag sequence: `` at
# Word 'mighty' current best two-tag sequence: at jj
# Word 'fine' current best two-tag sequence: ql jj
# Word 'thing' current best two-tag sequence: jj nn
# Word '''' current best two-tag sequence: nn ''
# Word ',' current best two-tag sequence: '' ,
# Word 'but' current best two-tag sequence: , cc
# Word 'made' current best two-tag sequence: cc vbd
# Word 'no' current best two-tag sequence: vbd at
# Word 'prediction' current best two-tag sequence: at nn
# Word 'on' current best two-tag sequence: nn in
# Word 'its' current best two-tag sequence: in pp$
# Word 'fate' current best two-tag sequence: pp$ nn
# Word 'in' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'House' current best two-tag sequence: at nn-tl
# Word '.' current best two-tag sequence: nn-tl .
# The sentence was: House Speaker Sam Rayburn ( D. , Tex. ) called the Kennedy program `` a mighty fine thing '' , but made no prediction on its fate in the House .
#
# The best tag sequence is: start nn-tl nn-tl np np ( np , np ) vbd at np nn `` at ql jj nn '' , cc vbd at nn in pp$ nn in at nn-tl . end
#
# The probability of the best tag sequence is: 7.778780465356743e-87
# Word 'The' current best two-tag sequence: start at
# Word 'rule' current best two-tag sequence: at nn
# Word 'was' current best two-tag sequence: nn bedz
# Word 'enforced' current best two-tag sequence: bedz vbn
# Word 'by' current best two-tag sequence: vbn in
# Word 'demand' current best two-tag sequence: in nn
# Word 'of' current best two-tag sequence: nn in
# Word 'Sen.' current best two-tag sequence: in nn-tl
# Word 'Wayne' current best two-tag sequence: nn-tl np
# Word 'Morse' current best two-tag sequence: np np
# Word '(' current best two-tag sequence: np (
# Word 'D.' current best two-tag sequence: ( np
# Word ',' current best two-tag sequence: np ,
# Word 'Ore.' current best two-tag sequence: , np
# Word ')' current best two-tag sequence: np )
# Word 'in' current best two-tag sequence: ) in
# Word 'connection' current best two-tag sequence: in nn
# Word 'with' current best two-tag sequence: nn in
# Word 'President' current best two-tag sequence: in nn-tl
# Word 'Eisenhower's' current best two-tag sequence: nn-tl np$
# Word 'cabinet' current best two-tag sequence: np$ nn
# Word 'selections' current best two-tag sequence: nn nns
# Word 'in' current best two-tag sequence: nns in
# Word '1953' current best two-tag sequence: in cd
# Word 'and' current best two-tag sequence: cd cc
# Word 'President' current best two-tag sequence: cc nn-tl
# Word 'Kennedy's' current best two-tag sequence: nn-tl np$
# Word 'in' current best two-tag sequence: np$ in
# Word '1961' current best two-tag sequence: in cd
# Word '.' current best two-tag sequence: cd .
# The sentence was: The rule was enforced by demand of Sen. Wayne Morse ( D. , Ore. ) in connection with President Eisenhower's cabinet selections in 1953 and President Kennedy's in 1961 .
#
# The best tag sequence is: start at nn bedz vbn in nn in nn-tl np np ( np , np ) in nn in nn-tl np$ nn nns in cd cc nn-tl np$ in cd . end
#
# The probability of the best tag sequence is: 5.4053474427923603e-95
# Word 'Several' current best two-tag sequence: start ap
# Word 'defendants' current best two-tag sequence: ap nns
# Word 'in' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'Summerdale' current best two-tag sequence: at np
# Word 'police' current best two-tag sequence: np nn
# Word 'burglary' current best two-tag sequence: nn nn
# Word 'trial' current best two-tag sequence: nn nn
# Word 'made' current best two-tag sequence: nn vbd
# Word 'statements' current best two-tag sequence: vbn nns
# Word 'indicating' current best two-tag sequence: nns vbg
# Word 'their' current best two-tag sequence: vbg pp$
# Word 'guilt' current best two-tag sequence: pp$ nn
# Word 'at' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'time' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'their' current best two-tag sequence: in pp$
# Word 'arrest' current best two-tag sequence: pp$ nn
# Word ',' current best two-tag sequence: nn ,
# Word 'Judge' current best two-tag sequence: , nn-tl
# Word 'James' current best two-tag sequence: nn-tl np
# Word 'B.' current best two-tag sequence: np np
# Word 'Parsons' current best two-tag sequence: np np
# Word 'was' current best two-tag sequence: np bedz
# Word 'told' current best two-tag sequence: bedz vbn
# Word 'in' current best two-tag sequence: vbn in
# Word 'Criminal' current best two-tag sequence: fw-uh-tl at
# Word 'court' current best two-tag sequence: fw-uh-tl at
# Word 'yesterday' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: Several defendants in the Summerdale police burglary trial made statements indicating their guilt at the time of their arrest , Judge James B. Parsons was told in Criminal court yesterday .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'Reaction' current best two-tag sequence: start nn-hl
# Word 'as' current best two-tag sequence: nn-hl cs-hl
# Word 'expected' current best two-tag sequence: cs-hl vbn-hl
# The sentence was: Reaction as expected
#
# The best tag sequence is: start nn-hl cs-hl vbn-hl end
#
# The probability of the best tag sequence is: 1.1965593656103893e-12
# Word 'Karns' current best two-tag sequence: start at
# Word 'said' current best two-tag sequence: fw-uh-tl at
# Word 'that' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'cases' current best two-tag sequence: fw-uh-tl at
# Word 'involved' current best two-tag sequence: fw-uh-tl at
# Word 'a' current best two-tag sequence: fw-uh-tl at
# Word 'matter' current best two-tag sequence: fw-uh-tl at
# Word '``' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'even' current best two-tag sequence: fw-uh-tl at
# Word 'greater' current best two-tag sequence: fw-uh-tl at
# Word 'significance' current best two-tag sequence: fw-uh-tl at
# Word 'than' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'guilt' current best two-tag sequence: fw-uh-tl at
# Word 'or' current best two-tag sequence: fw-uh-tl at
# Word 'innocence' current best two-tag sequence: fw-uh-tl at
# Word '''' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word '50' current best two-tag sequence: fw-uh-tl at
# Word 'persons' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: Karns said that the cases involved a matter `` of even greater significance than the guilt or innocence '' of the 50 persons .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'In' current best two-tag sequence: start in
# Word 'the' current best two-tag sequence: in at
# Word 'child' current best two-tag sequence: at nn
# Word 'health' current best two-tag sequence: nn nn
# Word 'field' current best two-tag sequence: nn nn
# Word ',' current best two-tag sequence: nn ,
# Word 'the' current best two-tag sequence: , at
# Word 'President' current best two-tag sequence: at nn-tl
# Word 'said' current best two-tag sequence: nn-tl vbd
# Word 'he' current best two-tag sequence: vbd pps
# Word 'will' current best two-tag sequence: pps md
# Word 'recommend' current best two-tag sequence: md vb
# Word 'later' current best two-tag sequence: vb rbr
# Word 'an' current best two-tag sequence: rbr at
# Word 'increase' current best two-tag sequence: at nn
# Word 'in' current best two-tag sequence: nn in
# Word 'funds' current best two-tag sequence: in nns
# Word 'for' current best two-tag sequence: nns in
# Word 'programs' current best two-tag sequence: in nns
# Word 'under' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'children's' current best two-tag sequence: at nns$
# Word 'bureau' current best two-tag sequence: nns$ nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: In the child health field , the President said he will recommend later an increase in funds for programs under the children's bureau .
#
# The best tag sequence is: start in at nn nn nn , at nn-tl vbd pps md vb rbr at nn in nns in nns in at nns$ nn . end
#
# The probability of the best tag sequence is: 1.5412193381236264e-65
# Word 'Other' current best two-tag sequence: start ap
# Word 'parts' current best two-tag sequence: ap nns
# Word 'of' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'Kennedy' current best two-tag sequence: at np
# Word 'health' current best two-tag sequence: np nn
# Word 'plan' current best two-tag sequence: nn nn
# Word 'would' current best two-tag sequence: nn md
# Word 'entail' current best two-tag sequence: md vb
# Word 'federal' current best two-tag sequence: vb jj
# Word 'grants' current best two-tag sequence: jj nns
# Word 'of' current best two-tag sequence: nns in
# Word '750' current best two-tag sequence: in cd
# Word 'million' current best two-tag sequence: cd cd
# Word 'to' current best two-tag sequence: cd in
# Word '1' current best two-tag sequence: in cd
# Word 'billion' current best two-tag sequence: cd cd
# Word 'dollars' current best two-tag sequence: cd nns
# Word 'over' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'next' current best two-tag sequence: at ap
# Word '10' current best two-tag sequence: ap cd
# Word 'years' current best two-tag sequence: cd nns
# Word '.' current best two-tag sequence: nns .
# The sentence was: Other parts of the Kennedy health plan would entail federal grants of 750 million to 1 billion dollars over the next 10 years .
#
# The best tag sequence is: start ap nns in at np nn nn md vb jj nns in cd cd in cd cd nns in at ap cd nns . end
#
# The probability of the best tag sequence is: 9.288086942387648e-74
# Word 'It' current best two-tag sequence: start pps
# Word 'includes' current best two-tag sequence: pps vbz
# Word 'a' current best two-tag sequence: vbz at
# Word 'raise' current best two-tag sequence: at nn
# Word 'in' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'county' current best two-tag sequence: at nn
# Word 'minimum' current best two-tag sequence: nn nn
# Word 'wage' current best two-tag sequence: jj nn
# Word ',' current best two-tag sequence: nn ,
# Word 'creation' current best two-tag sequence: , nn
# Word 'of' current best two-tag sequence: nn in
# Word 'several' current best two-tag sequence: in ap
# Word 'new' current best two-tag sequence: ap jj
# Word 'jobs' current best two-tag sequence: jj nns
# Word 'at' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'executive' current best two-tag sequence: at nn
# Word 'level' current best two-tag sequence: jj nn
# Word ',' current best two-tag sequence: nn ,
# Word 'financing' current best two-tag sequence: , vbg
# Word 'of' current best two-tag sequence: vbg in
# Word 'beefed-up' current best two-tag sequence: in jj
# Word 'industrial' current best two-tag sequence: jj jj
# Word 'development' current best two-tag sequence: jj nn
# Word 'efforts' current best two-tag sequence: nn nns
# Word ',' current best two-tag sequence: nns ,
# Word 'and' current best two-tag sequence: , cc
# Word 'increased' current best two-tag sequence: cc vbn
# Word 'expenditures' current best two-tag sequence: vbn nns
# Word 'for' current best two-tag sequence: nns in
# Word 'essential' current best two-tag sequence: in jj
# Word 'services' current best two-tag sequence: jj nns
# Word 'such' current best two-tag sequence: nns jj
# Word 'as' current best two-tag sequence: jj cs
# Word 'health' current best two-tag sequence: cs nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'welfare' current best two-tag sequence: cc nn
# Word ',' current best two-tag sequence: nn ,
# Word 'fire' current best two-tag sequence: , nn
# Word 'protection' current best two-tag sequence: nn nn
# Word ',' current best two-tag sequence: nn ,
# Word 'sanitation' current best two-tag sequence: , nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'road' current best two-tag sequence: cc nn
# Word 'maintenance' current best two-tag sequence: nn nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: It includes a raise in the county minimum wage , creation of several new jobs at the executive level , financing of beefed-up industrial development efforts , and increased expenditures for essential services such as health and welfare , fire protection , sanitation and road maintenance .
#
# The best tag sequence is: start pps vbz at nn in at nn jj nn , nn in ap jj nns in at jj nn , vbg in jj jj nn nns , cc vbn nns in jj nns jj cs nn cc nn , nn nn , nn cc nn nn . end
#
# The probability of the best tag sequence is: 4.9721017259956815e-142
# Word 'The' current best two-tag sequence: start at
# Word 'danger' current best two-tag sequence: at nn
# Word 'lay' current best two-tag sequence: nn vbd
# Word 'in' current best two-tag sequence: vbd in
# Word 'the' current best two-tag sequence: in at
# Word 'American' current best two-tag sequence: at jj
# Word 'delusion' current best two-tag sequence: jj nn
# Word 'that' current best two-tag sequence: nn cs
# Word 'nuclear' current best two-tag sequence: cs jj
# Word 'deterrence' current best two-tag sequence: fw-uh-tl at
# Word 'was' current best two-tag sequence: fw-uh-tl at
# Word 'enough' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: The danger lay in the American delusion that nuclear deterrence was enough .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'These' current best two-tag sequence: start dts
# Word 'women' current best two-tag sequence: dts nns
# Word 'whose' current best two-tag sequence: nns wp$
# Word 'organization' current best two-tag sequence: wp$ nn
# Word 'grew' current best two-tag sequence: nn vbd
# Word 'out' current best two-tag sequence: vbd rp
# Word 'of' current best two-tag sequence: rp in
# Word 'the' current best two-tag sequence: in at
# Word 'old' current best two-tag sequence: at jj
# Word 'suffrage' current best two-tag sequence: jj nn
# Word 'movement' current best two-tag sequence: nn nn
# Word 'are' current best two-tag sequence: nn ber
# Word 'dedicated' current best two-tag sequence: ber vbn
# Word 'to' current best two-tag sequence: vbn to
# Word 'Thomas' current best two-tag sequence: in np
# Word 'Jefferson's' current best two-tag sequence: np np$
# Word 'dictum' current best two-tag sequence: np$ nn
# Word 'that' current best two-tag sequence: nn cs
# Word 'one' current best two-tag sequence: cs pn
# Word 'must' current best two-tag sequence: pn md
# Word 'cherish' current best two-tag sequence: md vb
# Word 'the' current best two-tag sequence: vb at
# Word 'people's' current best two-tag sequence: at nns$
# Word 'spirit' current best two-tag sequence: nns$ nn
# Word 'but' current best two-tag sequence: nn cc
# Word '``' current best two-tag sequence: cc ``
# Word 'Keep' current best two-tag sequence: `` vb-tl
# Word 'alive' current best two-tag sequence: vb jj
# Word 'their' current best two-tag sequence: jj pp$
# Word 'attention' current best two-tag sequence: pp$ nn
# Word '''' current best two-tag sequence: nn ''
# Word '.' current best two-tag sequence: '' .
# The sentence was: These women whose organization grew out of the old suffrage movement are dedicated to Thomas Jefferson's dictum that one must cherish the people's spirit but `` Keep alive their attention '' .
#
# The best tag sequence is: start dts nns wp$ nn vbd rp in at jj nn nn ber vbn in np np$ nn cs pn md vb at nns$ nn cc `` vb jj pp$ nn '' . end
#
# The probability of the best tag sequence is: 4.564701651722478e-97
# Word 'Coupling' current best two-tag sequence: start at
# Word 'its' current best two-tag sequence: fw-uh-tl at
# Word 'own' current best two-tag sequence: fw-uh-tl at
# Word 'budget' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word '$83,750' current best two-tag sequence: fw-uh-tl at
# Word 'with' current best two-tag sequence: fw-uh-tl at
# Word 'a' current best two-tag sequence: fw-uh-tl at
# Word '$30,000' current best two-tag sequence: fw-uh-tl at
# Word 'state' current best two-tag sequence: fw-uh-tl at
# Word 'grant' current best two-tag sequence: fw-uh-tl at
# Word 'authorized' current best two-tag sequence: fw-uh-tl at
# Word 'by' current best two-tag sequence: fw-uh-tl at
# Word 'Gov.' current best two-tag sequence: fw-uh-tl at
# Word 'Vandiver' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'group' current best two-tag sequence: fw-uh-tl at
# Word 'expects' current best two-tag sequence: fw-uh-tl at
# Word 'to' current best two-tag sequence: fw-uh-tl at
# Word 'sign' current best two-tag sequence: fw-uh-tl at
# Word 'a' current best two-tag sequence: fw-uh-tl at
# Word 'contract' current best two-tag sequence: fw-uh-tl at
# Word 'in' current best two-tag sequence: fw-uh-tl at
# Word 'March' current best two-tag sequence: fw-uh-tl at
# Word 'with' current best two-tag sequence: fw-uh-tl at
# Word 'Georgia' current best two-tag sequence: fw-uh-tl at
# Word 'Tech.' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: Coupling its own budget of $83,750 with a $30,000 state grant authorized by Gov. Vandiver , the group expects to sign a contract in March with Georgia Tech. .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'Start' current best two-tag sequence: start nn-hl
# Word 'on' current best two-tag sequence: nn-hl in-hl
# Word 'rapid' current best two-tag sequence: in jj
# Word 'transit' current best two-tag sequence: jj nn
# The sentence was: Start on rapid transit
#
# The best tag sequence is: start vb in jj nn end
#
# The probability of the best tag sequence is: 2.530021223923106e-20
# Word 'Fortunately' current best two-tag sequence: start rb
# Word 'it' current best two-tag sequence: rb pps
# Word 'spared' current best two-tag sequence: pps vbd
# Word 'us' current best two-tag sequence: vbd ppo
# Word 'from' current best two-tag sequence: ppo in
# Word 'the' current best two-tag sequence: in at
# Word 'usual' current best two-tag sequence: at jj
# Word 'spate' current best two-tag sequence: jj nn
# Word 'of' current best two-tag sequence: nn in
# Word 'silly' current best two-tag sequence: in jj
# Word 'resolutions' current best two-tag sequence: jj nns
# Word 'which' current best two-tag sequence: nns wdt
# Word 'in' current best two-tag sequence: wdt in
# Word 'the' current best two-tag sequence: in at
# Word 'past' current best two-tag sequence: at nn
# Word 'have' current best two-tag sequence: nn hv
# Word 'made' current best two-tag sequence: hv vbn
# Word 'Georgia' current best two-tag sequence: vbn np
# Word 'look' current best two-tag sequence: np vb
# Word 'like' current best two-tag sequence: vb cs
# Word 'anything' current best two-tag sequence: cs pn
# Word 'but' current best two-tag sequence: pn cc
# Word '``' current best two-tag sequence: cc ``
# Word 'the' current best two-tag sequence: `` at
# Word 'empire' current best two-tag sequence: at nn
# Word 'state' current best two-tag sequence: nn nn
# Word 'of' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'South' current best two-tag sequence: at nr-tl
# Word '''' current best two-tag sequence: nr-tl ''
# Word '.' current best two-tag sequence: '' .
# The sentence was: Fortunately it spared us from the usual spate of silly resolutions which in the past have made Georgia look like anything but `` the empire state of the South '' .
#
# The best tag sequence is: start rb pps vbd ppo in at jj nn in jj nns wdt in at nn hv vbn np vb cs pn cc `` at nn nn in at nr-tl '' . end
#
# The probability of the best tag sequence is: 1.4512101929727379e-88
# Word 'Only' current best two-tag sequence: start rb
# Word 'a' current best two-tag sequence: rb at
# Word 'token' current best two-tag sequence: at jj
# Word 'start' current best two-tag sequence: jj nn
# Word 'was' current best two-tag sequence: nn bedz
# Word 'made' current best two-tag sequence: bedz vbn
# Word 'in' current best two-tag sequence: vbn in
# Word 'attacking' current best two-tag sequence: in vbg
# Word 'the' current best two-tag sequence: vbg at
# Word 'tax' current best two-tag sequence: at nn
# Word 'reappraisal' current best two-tag sequence: nn nn
# Word 'question' current best two-tag sequence: nn nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'its' current best two-tag sequence: cc pp$
# Word 'companion' current best two-tag sequence: pp$ nn
# Word 'issue' current best two-tag sequence: nn nn
# Word 'of' current best two-tag sequence: nn in
# Word 'attracting' current best two-tag sequence: in vbg
# Word 'industry' current best two-tag sequence: vbg nn
# Word 'to' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'state' current best two-tag sequence: at nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: Only a token start was made in attacking the tax reappraisal question and its companion issue of attracting industry to the state .
#
# The best tag sequence is: start rb at jj nn bedz vbn in vbg at nn nn nn cc pp$ nn nn in vbg nn in at nn . end
#
# The probability of the best tag sequence is: 2.9518975251626498e-68
# Word 'Then' current best two-tag sequence: start rb
# Word 'he' current best two-tag sequence: rb pps
# Word 'arrived' current best two-tag sequence: pps vbd
# Word 'in' current best two-tag sequence: vbd in
# Word 'Zanzibar' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word 'found' current best two-tag sequence: fw-uh-tl at
# Word 'Africans' current best two-tag sequence: fw-uh-tl at
# Word 'carrying' current best two-tag sequence: fw-uh-tl at
# Word 'signs' current best two-tag sequence: fw-uh-tl at
# Word 'saying' current best two-tag sequence: fw-uh-tl at
# Word '``' current best two-tag sequence: fw-uh-tl at
# Word 'American' current best two-tag sequence: fw-uh-tl at
# Word 'imperialists' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'go' current best two-tag sequence: fw-uh-tl at
# Word 'home' current best two-tag sequence: fw-uh-tl at
# Word '''' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: Then he arrived in Zanzibar and found Africans carrying signs saying `` American imperialists , go home '' .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'The' current best two-tag sequence: start at
# Word 'legislature' current best two-tag sequence: at nn
# Word 'expended' current best two-tag sequence: nn vbn
# Word 'most' current best two-tag sequence: vbn ql
# Word 'of' current best two-tag sequence: ap in
# Word 'its' current best two-tag sequence: in pp$
# Word 'time' current best two-tag sequence: pp$ nn
# Word 'on' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'schools' current best two-tag sequence: at nns
# Word 'and' current best two-tag sequence: nns cc
# Word 'appropriations' current best two-tag sequence: cc nns
# Word 'questions' current best two-tag sequence: nns nns
# Word '.' current best two-tag sequence: nns .
# The sentence was: The legislature expended most of its time on the schools and appropriations questions .
#
# The best tag sequence is: start at nn vbn ap in pp$ nn in at nns cc nns nns . end
#
# The probability of the best tag sequence is: 4.918904652142206e-41
# Word 'Somewhere' current best two-tag sequence: start rb
# Word ',' current best two-tag sequence: rb ,
# Word 'somebody' current best two-tag sequence: , pn
# Word 'is' current best two-tag sequence: pn bez
# Word 'bound' current best two-tag sequence: bez vbn
# Word 'to' current best two-tag sequence: vbn to
# Word 'love' current best two-tag sequence: to vb
# Word 'us' current best two-tag sequence: vb ppo
# The sentence was: Somewhere , somebody is bound to love us
#
# The best tag sequence is: start rb , pn bez vbn to vb-hl ppo-hl end
#
# The probability of the best tag sequence is: 1.1487275616137908e-25
# Word 'To' current best two-tag sequence: start in
# Word 'pick' current best two-tag sequence: to vb
# Word 'out' current best two-tag sequence: vb rp
# Word 'particular' current best two-tag sequence: rp jj
# Word 'numbers' current best two-tag sequence: jj nns
# Word 'is' current best two-tag sequence: nns bez
# Word 'something' current best two-tag sequence: bez pn
# Word 'of' current best two-tag sequence: pn in
# Word 'a' current best two-tag sequence: in at
# Word 'problem' current best two-tag sequence: at nn
# Word ',' current best two-tag sequence: nn ,
# Word 'but' current best two-tag sequence: , cc
# Word 'one' current best two-tag sequence: cc cd
# Word 'or' current best two-tag sequence: cd cc
# Word 'two' current best two-tag sequence: cc cd
# Word 'identifiable' current best two-tag sequence: cd jj
# Word 'items' current best two-tag sequence: jj nns
# Word 'are' current best two-tag sequence: nns ber
# Word 'too' current best two-tag sequence: ber ql
# Word 'conspicuously' current best two-tag sequence: ql rb
# Word 'excellent' current best two-tag sequence: ql jj
# Word 'to' current best two-tag sequence: jj to
# Word 'be' current best two-tag sequence: to be
# Word 'missed' current best two-tag sequence: be vbn
# Word '.' current best two-tag sequence: vbn .
# The sentence was: To pick out particular numbers is something of a problem , but one or two identifiable items are too conspicuously excellent to be missed .
#
# The best tag sequence is: start to vb rp jj nns bez pn in at nn , cc cd cc cd jj nns ber ql ql jj to be vbn . end
#
# The probability of the best tag sequence is: 6.302086890173555e-68
# Word 'On' current best two-tag sequence: start in
# Word 'the' current best two-tag sequence: in at
# Word 'whole' current best two-tag sequence: at jj
# Word 'this' current best two-tag sequence: jj dt
# Word 'is' current best two-tag sequence: dt bez
# Word 'an' current best two-tag sequence: bez at
# Word 'interesting' current best two-tag sequence: at jj
# Word 'and' current best two-tag sequence: jj cc
# Word 'exceptionally' current best two-tag sequence: cc ql
# Word 'well-written' current best two-tag sequence: fw-uh-tl at
# Word 'book' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: On the whole this is an interesting and exceptionally well-written book .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'A' current best two-tag sequence: start at
# Word 'bunch' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'young' current best two-tag sequence: in jj
# Word 'buckaroos' current best two-tag sequence: fw-uh-tl at
# Word 'from' current best two-tag sequence: fw-uh-tl at
# Word 'out' current best two-tag sequence: fw-uh-tl at
# Word 'West' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'who' current best two-tag sequence: fw-uh-tl at
# Word 'go' current best two-tag sequence: fw-uh-tl at
# Word 'by' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'name' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'Texas' current best two-tag sequence: fw-uh-tl at
# Word 'Boys' current best two-tag sequence: fw-uh-tl at
# Word 'Choir' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'loped' current best two-tag sequence: fw-uh-tl at
# Word 'into' current best two-tag sequence: fw-uh-tl at
# Word 'Town' current best two-tag sequence: fw-uh-tl at
# Word 'Hall' current best two-tag sequence: fw-uh-tl at
# Word 'last' current best two-tag sequence: fw-uh-tl at
# Word 'night' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word 'succeeded' current best two-tag sequence: fw-uh-tl at
# Word 'in' current best two-tag sequence: fw-uh-tl at
# Word 'corralling' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'hearts' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# Word 'a' current best two-tag sequence: fw-uh-tl at
# Word 'sizable' current best two-tag sequence: fw-uh-tl at
# Word 'audience' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: A bunch of young buckaroos from out West , who go by the name of Texas Boys Choir , loped into Town Hall last night and succeeded in corralling the hearts of a sizable audience .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'One' current best two-tag sequence: start cd
# Word 'of' current best two-tag sequence: cd in
# Word 'the' current best two-tag sequence: in at
# Word 'very' current best two-tag sequence: at ql
# Word 'best' current best two-tag sequence: ql rbt
# Word 'is' current best two-tag sequence: rbt bez
# Word 'only' current best two-tag sequence: bez rb
# Word 'now' current best two-tag sequence: rb rb
# Word 'published' current best two-tag sequence: rb vbn
# Word 'in' current best two-tag sequence: vbn in
# Word 'this' current best two-tag sequence: in dt
# Word 'country' current best two-tag sequence: dt nn
# Word ',' current best two-tag sequence: nn ,
# Word 'five' current best two-tag sequence: , cd
# Word 'years' current best two-tag sequence: cd nns
# Word 'after' current best two-tag sequence: nns in
# Word 'its' current best two-tag sequence: in pp$
# Word 'first' current best two-tag sequence: pp$ od
# Word 'publication' current best two-tag sequence: od nn
# Word 'in' current best two-tag sequence: nn in
# Word 'England' current best two-tag sequence: in np
# Word '.' current best two-tag sequence: np .
# The sentence was: One of the very best is only now published in this country , five years after its first publication in England .
#
# The best tag sequence is: start cd in at ql rbt bez rb rb vbn in dt nn , cd nns in pp$ od nn in np . end
#
# The probability of the best tag sequence is: 1.938557881216498e-54
# Word 'it' current best two-tag sequence: start pps
# Word 'is' current best two-tag sequence: pps bez
# Word 'more' current best two-tag sequence: bez ql
# Word 'likely' current best two-tag sequence: ql jj
# Word 'the' current best two-tag sequence: rb at
# Word 'sons' current best two-tag sequence: at nns
# Word 'and' current best two-tag sequence: nns cc
# Word 'daughters' current best two-tag sequence: cc nns
# Word 'of' current best two-tag sequence: nns in
# Word 'that' current best two-tag sequence: in dt
# Word 'company' current best two-tag sequence: dt nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: it is more likely the sons and daughters of that company .
#
# The best tag sequence is: start pps bez ql rb at nns cc nns in dt nn . end
#
# The probability of the best tag sequence is: 3.5656195742587697e-29
# Word 'This' current best two-tag sequence: start dt
# Word 'was' current best two-tag sequence: dt bedz
# Word 'not' current best two-tag sequence: bedz *
# Word 'an' current best two-tag sequence: * at
# Word 'overriding' current best two-tag sequence: at vbg
# Word 'drawback' current best two-tag sequence: vbg nn
# Word 'to' current best two-tag sequence: nn in
# Word 'enjoyment' current best two-tag sequence: in nn
# Word 'of' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'performances' current best two-tag sequence: at nns
# Word ',' current best two-tag sequence: nns ,
# Word 'however' current best two-tag sequence: , rb
# Word ',' current best two-tag sequence: rb ,
# Word 'except' current best two-tag sequence: , in
# Word 'in' current best two-tag sequence: rb in
# Word 'the' current best two-tag sequence: in at
# Word 'case' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'opening' current best two-tag sequence: at nn
# Word 'work' current best two-tag sequence: vbg nn
# Word ',' current best two-tag sequence: nn ,
# Word 'Mozart's' current best two-tag sequence: fw-uh-tl at
# Word 'Sonata' current best two-tag sequence: fw-uh-tl at
# Word 'in' current best two-tag sequence: fw-uh-tl at
# Word 'A' current best two-tag sequence: fw-uh-tl at
# Word '(' current best two-tag sequence: fw-uh-tl at
# Word 'K.' current best two-tag sequence: fw-uh-tl at
# Word '526' current best two-tag sequence: fw-uh-tl at
# Word ')' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'which' current best two-tag sequence: fw-uh-tl at
# Word 'clattered' current best two-tag sequence: fw-uh-tl at
# Word 'along' current best two-tag sequence: fw-uh-tl at
# Word 'noisily' current best two-tag sequence: fw-uh-tl at
# Word 'in' current best two-tag sequence: fw-uh-tl at
# Word 'an' current best two-tag sequence: fw-uh-tl at
# Word 'unrelieved' current best two-tag sequence: fw-uh-tl at
# Word 'fashion' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: This was not an overriding drawback to enjoyment of the performances , however , except in the case of the opening work , Mozart's Sonata in A ( K. 526 ) , which clattered along noisily in an unrelieved fashion .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'Boys' current best two-tag sequence: start nns
# Word 'will' current best two-tag sequence: nns md
# Word 'be' current best two-tag sequence: md be
# Word 'boys' current best two-tag sequence: be nns
# Word ',' current best two-tag sequence: nns ,
# Word 'and' current best two-tag sequence: , cc
# Word 'Texans' current best two-tag sequence: cc nps
# Word 'will' current best two-tag sequence: nps md
# Word 'be' current best two-tag sequence: md be
# Word 'Texans' current best two-tag sequence: be nps
# Word '.' current best two-tag sequence: nps .
# The sentence was: Boys will be boys , and Texans will be Texans .
#
# The best tag sequence is: start nns md be nns , cc nps md be nps . end
#
# The probability of the best tag sequence is: 6.517342168972157e-31
# Word 'administrative' current best two-tag sequence: start jj
# Word 'organization' current best two-tag sequence: jj nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'delicate' current best two-tag sequence: cc jj
# Word 'diplomatic' current best two-tag sequence: jj jj
# Word 'relations' current best two-tag sequence: jj nns
# Word 'with' current best two-tag sequence: nns in
# Word 'Top' current best two-tag sequence: in jjs
# Word 'Brass' current best two-tag sequence: fw-uh-tl at
# Word '--' current best two-tag sequence: fw-uh-tl at
# Word 'British' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'American' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word 'Chinese' current best two-tag sequence: fw-uh-tl at
# Word ';' current best two-tag sequence: fw-uh-tl at
# Word ';' current best two-tag sequence: fw-uh-tl at
# The sentence was: administrative organization and delicate diplomatic relations with Top Brass -- British , American and Chinese ; ;
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word '``' current best two-tag sequence: start ``
# Word 'The' current best two-tag sequence: `` at-tl
# Word 'commander' current best two-tag sequence: at nn
# Word 'has' current best two-tag sequence: nn hvz
# Word 'failed' current best two-tag sequence: hvz vbn
# Word 'in' current best two-tag sequence: vbn in
# Word 'his' current best two-tag sequence: in pp$
# Word 'duty' current best two-tag sequence: pp$ nn
# Word 'if' current best two-tag sequence: nn cs
# Word 'he' current best two-tag sequence: cs pps
# Word 'has' current best two-tag sequence: pps hvz
# Word 'not' current best two-tag sequence: hvz *
# Word 'won' current best two-tag sequence: * vbn
# Word 'victory' current best two-tag sequence: vbn nn
# Word '--' current best two-tag sequence: nn --
# Word 'for' current best two-tag sequence: -- in
# Word 'that' current best two-tag sequence: in dt
# Word 'is' current best two-tag sequence: dt bez
# Word 'his' current best two-tag sequence: bez pp$
# Word 'duty' current best two-tag sequence: pp$ nn
# Word '''' current best two-tag sequence: nn ''
# Word '.' current best two-tag sequence: '' .
# The sentence was: `` The commander has failed in his duty if he has not won victory -- for that is his duty '' .
#
# The best tag sequence is: start `` at nn hvz vbn in pp$ nn cs pps hvz * vbn nn -- in dt bez pp$ nn '' . end
#
# The probability of the best tag sequence is: 4.732376108735007e-53
# Word 'In' current best two-tag sequence: start in
# Word 'recent' current best two-tag sequence: in jj
# Word 'years' current best two-tag sequence: jj nns
# Word 'Anna' current best two-tag sequence: nns np
# Word 'Xydis' current best two-tag sequence: fw-uh-tl at
# Word 'has' current best two-tag sequence: fw-uh-tl at
# Word 'played' current best two-tag sequence: fw-uh-tl at
# Word 'with' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'New' current best two-tag sequence: fw-uh-tl at
# Word 'York' current best two-tag sequence: fw-uh-tl at
# Word 'Philharmonic' current best two-tag sequence: fw-uh-tl at
# Word 'and' current best two-tag sequence: fw-uh-tl at
# Word 'at' current best two-tag sequence: fw-uh-tl at
# Word 'Lewisohn' current best two-tag sequence: fw-uh-tl at
# Word 'Stadium' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'but' current best two-tag sequence: fw-uh-tl at
# Word 'her' current best two-tag sequence: fw-uh-tl at
# Word 'program' current best two-tag sequence: fw-uh-tl at
# Word 'last' current best two-tag sequence: fw-uh-tl at
# Word 'night' current best two-tag sequence: fw-uh-tl at
# Word 'at' current best two-tag sequence: fw-uh-tl at
# Word 'Town' current best two-tag sequence: fw-uh-tl at
# Word 'Hall' current best two-tag sequence: fw-uh-tl at
# Word 'was' current best two-tag sequence: fw-uh-tl at
# Word 'the' current best two-tag sequence: fw-uh-tl at
# Word 'Greek-born' current best two-tag sequence: fw-uh-tl at
# Word 'pianist's' current best two-tag sequence: fw-uh-tl at
# Word 'first' current best two-tag sequence: fw-uh-tl at
# Word 'New' current best two-tag sequence: fw-uh-tl at
# Word 'York' current best two-tag sequence: fw-uh-tl at
# Word 'recital' current best two-tag sequence: fw-uh-tl at
# Word 'since' current best two-tag sequence: fw-uh-tl at
# Word '1948' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: In recent years Anna Xydis has played with the New York Philharmonic and at Lewisohn Stadium , but her program last night at Town Hall was the Greek-born pianist's first New York recital since 1948 .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'And' current best two-tag sequence: start cc
# Word 'so' current best two-tag sequence: cc ql
# Word 'the' current best two-tag sequence: cs at
# Word 'psalmist' current best two-tag sequence: fw-uh-tl at
# Word 'gives' current best two-tag sequence: fw-uh-tl at
# Word 'us' current best two-tag sequence: fw-uh-tl at
# Word 'one' current best two-tag sequence: fw-uh-tl at
# Word 'more' current best two-tag sequence: fw-uh-tl at
# Word 'picture' current best two-tag sequence: fw-uh-tl at
# Word 'of' current best two-tag sequence: fw-uh-tl at
# ...
#
# The probability of the best tag sequence is: 0.0
# Word 'He' current best two-tag sequence: start pps
# Word 'was' current best two-tag sequence: pps bedz
# Word 'staring' current best two-tag sequence: bedz vbg
# Word 'at' current best two-tag sequence: vbg in
# Word 'the' current best two-tag sequence: in at
# Word 'blue' current best two-tag sequence: at jj
# Word 'china' current best two-tag sequence: jj nn
# Word 'lamp' current best two-tag sequence: nn nn
# Word 'left' current best two-tag sequence: nn vbd
# Word 'on' current best two-tag sequence: vbn in
# Word 'beside' current best two-tag sequence: rp in
# Word 'him' current best two-tag sequence: in ppo
# Word '.' current best two-tag sequence: ppo .
# The sentence was: He was staring at the blue china lamp left on beside him .
#
# The best tag sequence is: start pps bedz vbg in at jj nn nn vbd rp in ppo . end
#
# The probability of the best tag sequence is: 1.8348496343482327e-36
# Word '``' current best two-tag sequence: start ``
# Word 'Is' current best two-tag sequence: `` bez
# Word 'that' current best two-tag sequence: bez cs
# Word 'you' current best two-tag sequence: cs ppss
# Word ',' current best two-tag sequence: ppss ,
# Word 'Father' current best two-tag sequence: , nn-tl
# Word '?' current best two-tag sequence: nn-tl .
# Word '?' current best two-tag sequence: . .
# The sentence was: `` Is that you , Father ? ?
#
# The best tag sequence is: start `` bez cs ppss , nn-tl . . end
#
# The probability of the best tag sequence is: 8.345066033835073e-22
# Word 'How' current best two-tag sequence: start wrb
# Word 'did' current best two-tag sequence: wrb dod
# Word 'one' current best two-tag sequence: dod pn
# Word 'attach' current best two-tag sequence: pn vb
# Word 'anything' current best two-tag sequence: vb pn
# Word 'to' current best two-tag sequence: pn to
# Word 'a' current best two-tag sequence: in at
# Word 'stone' current best two-tag sequence: at nn
# Word 'wall' current best two-tag sequence: nn nn
# Word ',' current best two-tag sequence: nn ,
# Word 'for' current best two-tag sequence: , in
# Word 'that' current best two-tag sequence: in dt
# Word 'matter' current best two-tag sequence: dt nn
# Word '?' current best two-tag sequence: nn .
# Word '?' current best two-tag sequence: . .
# The sentence was: How did one attach anything to a stone wall , for that matter ? ?
#
# The best tag sequence is: start wrb dod pn vb pn in at nn nn , in dt nn . . end
#
# The probability of the best tag sequence is: 1.0960940000707203e-40
# Word 'Could' current best two-tag sequence: start md
# Word 'it' current best two-tag sequence: md-hl pps-hl
# Word 'be' current best two-tag sequence: pps-hl be-hl
# Word 'that' current best two-tag sequence: be cs
# Word 'it' current best two-tag sequence: cs pps
# Word 'speeded' current best two-tag sequence: pps vbd
# Word 'up' current best two-tag sequence: vbd rp
# Word 'for' current best two-tag sequence: rp in
# Word 'the' current best two-tag sequence: in at
# Word 'aged' current best two-tag sequence: at vbn
# Word 'in' current best two-tag sequence: vbn in
# Word 'some' current best two-tag sequence: in dti
# Word 'mysterious' current best two-tag sequence: dti jj
# Word 'way' current best two-tag sequence: jj nn
# Word ',' current best two-tag sequence: nn ,
# Word 'as' current best two-tag sequence: , cs
# Word 'if' current best two-tag sequence: cs cs
# Word 'a' current best two-tag sequence: cs at
# Word 'bored' current best two-tag sequence: at vbn
# Word 'universe' current best two-tag sequence: vbn nn
# Word 'were' current best two-tag sequence: nn bed
# Word 'skipping' current best two-tag sequence: bed vbg
# Word 'through' current best two-tag sequence: vbg in
# Word 'the' current best two-tag sequence: in at
# Word 'end' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'chapter' current best two-tag sequence: at nn
# Word 'just' current best two-tag sequence: nn rb
# Word 'to' current best two-tag sequence: rb to
# Word 'get' current best two-tag sequence: to vb
# Word 'it' current best two-tag sequence: vb ppo
# Word 'over' current best two-tag sequence: ppo rp
# Word 'with' current best two-tag sequence: rp in
# Word '?' current best two-tag sequence: in .
# Word '?' current best two-tag sequence: .-nc .-nc
# The sentence was: Could it be that it speeded up for the aged in some mysterious way , as if a bored universe were skipping through the end of the chapter just to get it over with ? ?
#
# The best tag sequence is: start md pps be cs pps vbd rp in at vbn in dti jj nn , cs cs at vbn nn bed vbg in at nn in at nn rb to vb ppo in in-nc .-nc .-nc end
#
# The probability of the best tag sequence is: 1.107036072774743e-95
# Word 'Perhaps' current best two-tag sequence: start rb
# Word 'one' current best two-tag sequence: rb cd
# Word 'bored' current best two-tag sequence: cd vbn
# Word 'holes' current best two-tag sequence: vbn nns
# Word 'in' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'stone' current best two-tag sequence: at nn
# Word 'with' current best two-tag sequence: nn in
# Word 'some' current best two-tag sequence: in dti
# Word 'kind' current best two-tag sequence: dti nn
# Word 'of' current best two-tag sequence: nn in
# Word 'an' current best two-tag sequence: in at
# Word 'electric' current best two-tag sequence: at jj
# Word 'gadget' current best two-tag sequence: jj nn
# Word '.' current best two-tag sequence: nn .
# The sentence was: Perhaps one bored holes in the stone with some kind of an electric gadget .
#
# The best tag sequence is: start rb cd vbn nns in at nn in dti nn in at jj nn . end
#
# The probability of the best tag sequence is: 3.2421272782919304e-43
# Word 'Up' current best two-tag sequence: start in
# Word 'to' current best two-tag sequence: rp in
# Word 'date' current best two-tag sequence: to vb
# Word ',' current best two-tag sequence: nn ,
# Word 'however' current best two-tag sequence: , rb
# Word ',' current best two-tag sequence: rb ,
# Word 'his' current best two-tag sequence: , pp$
# Word 'garden' current best two-tag sequence: pp$ nn
# Word 'was' current best two-tag sequence: nn bedz
# Word 'still' current best two-tag sequence: bedz rb
# Word 'more' current best two-tag sequence: rb ql
# Word 'or' current best two-tag sequence: rbr cc
# Word 'less' current best two-tag sequence: cc ap
# Word 'of' current best two-tag sequence: ap in
# Word 'a' current best two-tag sequence: in at
# Word 'mess' current best two-tag sequence: at nn
# Word ',' current best two-tag sequence: nn ,
# Word 'he' current best two-tag sequence: , pps
# Word 'hadn't' current best two-tag sequence: pps hvd*
# Word 'even' current best two-tag sequence: hvd* rb
# Word 'started' current best two-tag sequence: rb vbd
# Word 'his' current best two-tag sequence: vbd pp$
# Word 'workshop' current best two-tag sequence: pp$ nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'if' current best two-tag sequence: cc cs
# Word 'there' current best two-tag sequence: cs ex
# Word 'was' current best two-tag sequence: ex bedz
# Word 'a' current best two-tag sequence: bedz at
# Word 'meadow' current best two-tag sequence: at nn
# Word 'pond' current best two-tag sequence: nn nn
# Word 'in' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'neighborhood' current best two-tag sequence: at nn
# Word 'he' current best two-tag sequence: nn pps
# Word 'hadn't' current best two-tag sequence: pps hvd*
# Word 'found' current best two-tag sequence: hvd* vbn
# Word 'it' current best two-tag sequence: vbn ppo
# Word '.' current best two-tag sequence: ppo .
# The sentence was: Up to date , however , his garden was still more or less of a mess , he hadn't even started his workshop and if there was a meadow pond in the neighborhood he hadn't found it .
#
# The best tag sequence is: start rp in nn , rb , pp$ nn bedz rb rbr cc ap in at nn , pps hvd* rb vbd pp$ nn cc cs ex bedz at nn nn in at nn pps hvd* vbn ppo . end
#
# The probability of the best tag sequence is: 2.57658904398476e-96
# Word 'then' current best two-tag sequence: start rb
# Word 'a' current best two-tag sequence: rb at
# Word 'couple' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'fluorescent' current best two-tag sequence: in jj
# Word 'lamps' current best two-tag sequence: jj nns
# Word 'over' current best two-tag sequence: nns in
# Word 'the' current best two-tag sequence: in at
# Word 'workbench' current best two-tag sequence: fw-uh-tl at
# Word 'an'' current best two-tag sequence: fw-uh-tl at
# Word 'I' current best two-tag sequence: fw-uh-tl at
# Word 'guess' current best two-tag sequence: fw-uh-tl at
# Word 'we're' current best two-tag sequence: fw-uh-tl at
# Word 'about' current best two-tag sequence: fw-uh-tl at
# Word 'through' current best two-tag sequence: fw-uh-tl at
# Word 'down' current best two-tag sequence: fw-uh-tl at
# Word 'here' current best two-tag sequence: fw-uh-tl at
# Word '''' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: then a couple of fluorescent lamps over the workbench an' I guess we're about through down here '' .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word '``' current best two-tag sequence: start ``
# Word 'But' current best two-tag sequence: `` cc
# Word 'those' current best two-tag sequence: cc dts
# Word 'are' current best two-tag sequence: dts ber
# Word 'the' current best two-tag sequence: ber at
# Word 'things' current best two-tag sequence: at nns
# Word 'I' current best two-tag sequence: nns ppss
# Word 'built' current best two-tag sequence: ppss vbd
# Word 'the' current best two-tag sequence: vbd at
# Word 'workshop' current best two-tag sequence: at nn
# Word 'for' current best two-tag sequence: nn in
# Word '''' current best two-tag sequence: in ''
# Word ',' current best two-tag sequence: '' ,
# Word 'protested' current best two-tag sequence: , vbd
# Word 'Mr.' current best two-tag sequence: vbd np
# Word 'Crombie' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: `` But those are the things I built the workshop for '' , protested Mr. Crombie .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'It' current best two-tag sequence: start pps
# Word 'was' current best two-tag sequence: pps bedz
# Word 'five' current best two-tag sequence: bedz cd
# Word 'minutes' current best two-tag sequence: cd nns
# Word 'after' current best two-tag sequence: nns in
# Word 'four' current best two-tag sequence: in cd
# Word '.' current best two-tag sequence: cd .
# The sentence was: It was five minutes after four .
#
# The best tag sequence is: start pps bedz cd nns in cd . end
#
# The probability of the best tag sequence is: 2.6525770244294368e-17
# Word 'Mr.' current best two-tag sequence: start np
# Word 'Mills' current best two-tag sequence: np np
# Word 'had' current best two-tag sequence: np hvd
# Word 'done' current best two-tag sequence: hvd vbn
# Word 'some' current best two-tag sequence: vbn dti
# Word 'figuring' current best two-tag sequence: dti vbg
# Word 'on' current best two-tag sequence: vbg in
# Word 'a' current best two-tag sequence: in at
# Word 'scrap' current best two-tag sequence: at nn
# Word 'of' current best two-tag sequence: nn in
# Word 'paper' current best two-tag sequence: in nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'given' current best two-tag sequence: cc vbn
# Word 'him' current best two-tag sequence: vbn ppo
# Word 'the' current best two-tag sequence: ppo at
# Word 'various' current best two-tag sequence: at jj
# Word 'kinds' current best two-tag sequence: jj nns
# Word 'of' current best two-tag sequence: nns in
# Word 'boards' current best two-tag sequence: in nns
# Word 'and' current best two-tag sequence: nns cc
# Word 'two-by-fours' current best two-tag sequence: fw-uh-tl at
# Word 'which' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'properly' current best two-tag sequence: fw-uh-tl at
# Word 'handled' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'would' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'he' current best two-tag sequence: fw-uh-tl at
# Word 'had' current best two-tag sequence: fw-uh-tl at
# Word 'assured' current best two-tag sequence: fw-uh-tl at
# Word 'him' current best two-tag sequence: fw-uh-tl at
# Word ',' current best two-tag sequence: fw-uh-tl at
# Word 'turn' current best two-tag sequence: fw-uh-tl at
# Word 'into' current best two-tag sequence: fw-uh-tl at
# Word 'a' current best two-tag sequence: fw-uh-tl at
# Word 'workbench' current best two-tag sequence: fw-uh-tl at
# Word '.' current best two-tag sequence: fw-uh-tl at
# The sentence was: Mr. Mills had done some figuring on a scrap of paper and given him the various kinds of boards and two-by-fours which , properly handled , would , he had assured him , turn into a workbench .
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# Word 'Before' current best two-tag sequence: start cs
# Word 'you' current best two-tag sequence: cs ppss
# Word 'use' current best two-tag sequence: ppss vb
# Word ''em' current best two-tag sequence: vb ppo
# Word 'the' current best two-tag sequence: ppo at
# Word 'light' current best two-tag sequence: at nn
# Word 'company's' current best two-tag sequence: nn nn$
# Word 'got' current best two-tag sequence: nn+bez vbn
# Word 'to' current best two-tag sequence: vbn to
# Word 'run' current best two-tag sequence: to vb
# Word 'in' current best two-tag sequence: vb in
# Word 'a' current best two-tag sequence: in at
# Word 'heavy' current best two-tag sequence: at jj
# Word 'line' current best two-tag sequence: jj nn
# Word 'and' current best two-tag sequence: nn cc
# Word 'you'll' current best two-tag sequence: cc ppss+md
# Word 'need' current best two-tag sequence: ppss+md vb
# Word 'a' current best two-tag sequence: vb at
# Word 'new' current best two-tag sequence: at jj
# Word 'fuse' current best two-tag sequence: jj nn
# Word 'box' current best two-tag sequence: nn nn
# Word 'for' current best two-tag sequence: nn in
# Word 'the' current best two-tag sequence: in at
# Word 'extra' current best two-tag sequence: at jj
# Word 'circuits' current best two-tag sequence: jj nns
# Word '.' current best two-tag sequence: nns .
# The sentence was: Before you use 'em the light company's got to run in a heavy line and you'll need a new fuse box for the extra circuits .
#
# The best tag sequence is: start cs ppss vb ppo at jj nn+bez vbn to vb in at jj nn cc ppss+md vb at jj nn nn in at jj nns . end
#
# The probability of the best tag sequence is: 8.874790636055956e-74
# Word 'Did' current best two-tag sequence: start dod
# Word 'older' current best two-tag sequence: fw-uh-tl at
# Word 'people' current best two-tag sequence: fw-uh-tl at
# Word 'work' current best two-tag sequence: fw-uh-tl at
# Word 'more' current best two-tag sequence: fw-uh-tl at
# Word 'slowly' current best two-tag sequence: fw-uh-tl at
# Word '?' current best two-tag sequence: fw-uh-tl at
# Word '?' current best two-tag sequence: fw-uh-tl at
# The sentence was: Did older people work more slowly ? ?
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0

# %%
Viterbi(['He', 'goes', 'to', 'asdas', 'school'])
# Out:
# Word 'He' current best two-tag sequence: start pps
# Word 'goes' current best two-tag sequence: pps vbz
# Word 'to' current best two-tag sequence: vbz to
# Word 'asdas' current best two-tag sequence: fw-uh-tl at
# Word 'school' current best two-tag sequence: fw-uh-tl at
# fw-uh-tl    at
#
# fw-uh-tl    fw-uh-tl
#
# fw-uh-tl    fw-uh-tl
#
# fw-uh-tl    fw-uh-tl
#
# start    fw-uh-tl
#
# The sentence was: He goes to asdas school
#
# The best tag sequence is: start fw-uh-tl fw-uh-tl fw-uh-tl fw-uh-tl at end
#
# The probability of the best tag sequence is: 0.0
# ['start', 'fw-uh-tl', 'fw-uh-tl', 'fw-uh-tl', 'fw-uh-tl', 'at', 'end']
